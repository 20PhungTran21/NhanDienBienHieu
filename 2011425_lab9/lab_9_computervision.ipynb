# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install ultralytics -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 615.6/615.6 kB 9.9 MB/s eta 0:00:00

# %%
from ultralytics import YOLO

# %%
model = YOLO("yolov8m.pt")
# Out:
# ...
# 100%|██████████| 49.7M/49.7M [00:00<00:00, 274MB/s]

# %%
# !touch data.yaml

# %%
# !unzip "/content/drive/MyDrive/CHUONG TRINH DAI HOC/HocKi_VII/computer_vison/all_data.zip" -d "/content"

# %%
model.train(data = "/content/data.yaml", epochs = 10 )
# Out:
# Ultralytics YOLOv8.0.189 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
infer = YOLO('/content/runs/detect/train11/weights/last.pt')
infer.predict('/content/all_data/test/4_5_60.jpg', save=True, save_txt=True)
# Out:
# image 1/1 /content/all_data/test/4_5_60.jpg: 384x640 1 2011425_Winsmart, 27.0ms
# Speed: 3.2ms preprocess, 27.0ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/predict3
# 1 label saved to runs/detect/predict3/labels
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: '2011425_BachHoaXanh', 1: '2011425_DienMayChoLon', 2: '2011425_DienMayXanh', 3: '2011425_TheGioiDiDong', 4: '2011425_Winsmart'}
#  orig_img: array([[[191, 175, 168],
#          [191, 175, 168],
#          [190, 174, 167],
#          ...,
#          [152, 132, 121],
#          [152, 132, 121],
#          [152, 132, 121]],
#
#         [[187, 171, 164],
#          [189, 173, 166],
#          [191, 175, 168],
#          ...,
#          [152, 132, 121],
#          [152, 132, 121],
#          [152, 132, 121]],
#
#         [[190, 174, 167],
#          [192, 176, 169],
# ...

# %%
import locale
def getpreferredencoding(do_setlocale = True):
  return "UTF-8"
locale.getpreferredencoding = getpreferredencoding

# %%
# !yolo detect predict model= '/content/runs/detect/train11/weights/last.pt' source='/content/test.mp4/'
# Out:
# Ultralytics YOLOv8.0.189 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 218 layers, 25842655 parameters, 0 gradients
#
# video 1/1 (1/1177) /content/test.mp4: 384x640 1 2011425_DienMayChoLon, 106.4ms
# video 1/1 (2/1177) /content/test.mp4: 384x640 1 2011425_DienMayChoLon, 25.9ms
# video 1/1 (3/1177) /content/test.mp4: 384x640 1 2011425_DienMayChoLon, 25.9ms
# video 1/1 (4/1177) /content/test.mp4: 384x640 1 2011425_DienMayChoLon, 25.8ms
# video 1/1 (5/1177) /content/test.mp4: 384x640 1 2011425_DienMayChoLon, 25.9ms
# video 1/1 (6/1177) /content/test.mp4: 384x640 1 2011425_DienMayChoLon, 25.9ms
# video 1/1 (7/1177) /content/test.mp4: 384x640 1 2011425_DienMayChoLon, 25.8ms
# video 1/1 (8/1177) /content/test.mp4: 384x640 1 2011425_DienMayChoLon, 25.8ms
# video 1/1 (9/1177) /content/test.mp4: 384x640 1 2011425_DienMayChoLon, 25.8ms
# video 1/1 (10/1177) /content/test.mp4: 384x640 1 2011425_DienMayChoLon, 25.8ms
# ...

# %%
# !yolo predict source= /content/test.mp4
